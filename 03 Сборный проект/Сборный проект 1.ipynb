# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Открытие-файла-с-данными-и-изучение-общей-информации" data-toc-modified-id="Открытие-файла-с-данными-и-изучение-общей-информации-0.1"><span class="toc-item-num">0.1&nbsp;&nbsp;</span><a class="anchor" id="first">Открытие файла с данными и изучение общей информации</a></a></span><ul class="toc-item"><li><span><a href="#Импорт-pandas.-Запись-данных-в-data" data-toc-modified-id="Импорт-pandas.-Запись-данных-в-data-0.1.1"><span class="toc-item-num">0.1.1&nbsp;&nbsp;</span><a class="anchor" id="first-first">Импорт pandas. Запись данных в data</a></a></span></li><li><span><a href="#Изучение-данных" data-toc-modified-id="Изучение-данных-0.1.2"><span class="toc-item-num">0.1.2&nbsp;&nbsp;</span><a class="anchor" id="first-second">Изучение данных</a></a></span></li></ul></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-0.2"><span class="toc-item-num">0.2&nbsp;&nbsp;</span><a class="anchor" id="second">Подготовка данных</a></a></span><ul class="toc-item"><li><span><a href="#Замена-названий-столбцов" data-toc-modified-id="Замена-названий-столбцов-0.2.1"><span class="toc-item-num">0.2.1&nbsp;&nbsp;</span><a class="anchor" id="second-first">Замена названий столбцов</a></a></span></li><li><span><a href="#Изменение-типов-данных" data-toc-modified-id="Изменение-типов-данных-0.2.2"><span class="toc-item-num">0.2.2&nbsp;&nbsp;</span><a class="anchor" id="second-second">Изменение типов данных</a></a></span></li><li><span><a href="#Пропущенные-значения" data-toc-modified-id="Пропущенные-значения-0.2.3"><span class="toc-item-num">0.2.3&nbsp;&nbsp;</span><a class="anchor" id="second-third">Пропущенные значения</a></a></span></li><li><span><a href="#Новый-столбец:-суммарные-продажи-во-всех-регионах" data-toc-modified-id="Новый-столбец:-суммарные-продажи-во-всех-регионах-0.2.4"><span class="toc-item-num">0.2.4&nbsp;&nbsp;</span><a class="anchor" id="second-fourth">Новый столбец: суммарные продажи во всех регионах</a></a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-0.3"><span class="toc-item-num">0.3&nbsp;&nbsp;</span><a class="anchor" id="third">Исследовательский анализ данных</a></a></span><ul class="toc-item"><li><span><a href="#Количество-игр-за-все-периоды" data-toc-modified-id="Количество-игр-за-все-периоды-0.3.1"><span class="toc-item-num">0.3.1&nbsp;&nbsp;</span><a class="anchor" id="third-first">Количество игр за все периоды</a></a></span></li><li><span><a href="#Продажи-по-платформам" data-toc-modified-id="Продажи-по-платформам-0.3.2"><span class="toc-item-num">0.3.2&nbsp;&nbsp;</span><a class="anchor" id="third-second">Продажи по платформам</a></a></span></li><li><span><a href="#Какие-платформы-лидируют-по-продажам,-растут-или-падают" data-toc-modified-id="Какие-платформы-лидируют-по-продажам,-растут-или-падают-0.3.3"><span class="toc-item-num">0.3.3&nbsp;&nbsp;</span><a class="anchor" id="third-third">Какие платформы лидируют по продажам, растут или падают</a></a></span></li><li><span><a href="#«Ящик-с-усами»-по-глобальным-продажам-игр-в-разбивке-по-платформам" data-toc-modified-id="«Ящик-с-усами»-по-глобальным-продажам-игр-в-разбивке-по-платформам-0.3.4"><span class="toc-item-num">0.3.4&nbsp;&nbsp;</span><a class="anchor" id="third-fourth">«Ящик с усами» по глобальным продажам игр в разбивке по платформам</a></a></span></li><li><span><a href="#Влияние-на-продажи-внутри-одной-популярной-платформы" data-toc-modified-id="Влияние-на-продажи-внутри-одной-популярной-платформы-0.3.5"><span class="toc-item-num">0.3.5&nbsp;&nbsp;</span><a class="anchor" id="third-fifth">Влияние на продажи внутри одной популярной платформы</a></a></span></li><li><span><a href="#Общее-распределение-игр-по-жанрам" data-toc-modified-id="Общее-распределение-игр-по-жанрам-0.3.6"><span class="toc-item-num">0.3.6&nbsp;&nbsp;</span><a class="anchor" id="third-sixth">Общее распределение игр по жанрам</a></a></span></li></ul></li><li><span><a href="#Составление-портрета-пользователя-каждого-региона" data-toc-modified-id="Составление-портрета-пользователя-каждого-региона-0.4"><span class="toc-item-num">0.4&nbsp;&nbsp;</span><a class="anchor" id="fourth">Составление портрета пользователя каждого региона</a></a></span><ul class="toc-item"><li><span><a href="#Самые-популярные-платформы-(топ-5)" data-toc-modified-id="Самые-популярные-платформы-(топ-5)-0.4.1"><span class="toc-item-num">0.4.1&nbsp;&nbsp;</span><a class="anchor" id="fourth-first">Самые популярные платформы (топ-5)</a></a></span></li><li><span><a href="#Самые-популярные-жанры-(топ-5)" data-toc-modified-id="Самые-популярные-жанры-(топ-5)-0.4.2"><span class="toc-item-num">0.4.2&nbsp;&nbsp;</span><a class="anchor" id="fourth-second">Самые популярные жанры (топ-5)</a></a></span></li><li><span><a href="#Влияние-рейтинга-ESRB-на-продажи-в-отдельном-регионе" data-toc-modified-id="Влияние-рейтинга-ESRB-на-продажи-в-отдельном-регионе-0.4.3"><span class="toc-item-num">0.4.3&nbsp;&nbsp;</span><a class="anchor" id="fourth-third">Влияние рейтинга ESRB на продажи в отдельном регионе</a></a></span></li></ul></li><li><span><a href="#Проверка-гипотез" data-toc-modified-id="Проверка-гипотез-0.5"><span class="toc-item-num">0.5&nbsp;&nbsp;</span><a class="anchor" id="first">Проверка гипотез</a></a></span><ul class="toc-item"><li><span><a href="#Гипотеза-1" data-toc-modified-id="Гипотеза-1-0.5.1"><span class="toc-item-num">0.5.1&nbsp;&nbsp;</span><a class="anchor" id="fifth-first">Гипотеза 1</a></a></span></li><li><span><a href="#Гипотеза-2" data-toc-modified-id="Гипотеза-2-0.5.2"><span class="toc-item-num">0.5.2&nbsp;&nbsp;</span><a class="anchor" id="fifth-second">Гипотеза 2</a></a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-0.6"><span class="toc-item-num">0.6&nbsp;&nbsp;</span><a class="anchor" id="sixth">Общий вывод</a></a></span></li></ul></li><li><span><a href="#🏁-Итоги-ревью" data-toc-modified-id="🏁-Итоги-ревью-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>🏁 Итоги ревью</a></span></li></ul></div>

# %% [markdown]
# # Сборный проект
#
# Вы работаете в интернет-магазине «Стримчик», который продаёт по всему миру компьютерные игры. Из открытых источников доступны исторические данные о продажах игр, оценки пользователей и экспертов, жанры и платформы (например, Xbox или PlayStation). Вам нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.

# %% [markdown]
# <b>Цели проекта:</b>
# Выявить определяющие успешность игры закономерности.
#
# <b>Задачи проекта:</b>
# 1. провести предобработку данных;
# 2. провести исследовательский анализ данных,
#     - посмотреть, сколько игр выпускалось в разные годы,
#     - посмотреть, как менялись продажи по платформам,
#     - выбрать актуальный период,
#     - ответить на вопрос: "Какие платформы лидируют по продажам, растут или падают?"
#     - построить график «ящик с усами» по глобальным продажам игр в разбивке по платформам,
#     - посмотреть, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков,
#     - посмотрите на общее распределение игр по жанрам;
# 3. составить портрет пользователя каждого региона;
# 4. проверить гипотезы,
#     - Средние пользовательские рейтинги платформ Xbox One и PC одинаковые,
#     - Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.
#
# 5. сделать общие выводы.
#
# <b>Данные:</b>
# Данные из открытых источников о продажах игр, оценках пользователей и экспертов, жанрах и платформах.

# %% [markdown]
# <b>Описание данных</b>
# - <code>Name</code> — название игры
# - <code>Platform</code> — платформа
# - <code>Year_of_Release</code> — год выпуска
# - <code>Genre</code> — жанр игры
# - <code>NA_sales</code> — продажи в Северной Америке (миллионы проданных копий)
# - <code>EU_sales</code> — продажи в Европе (миллионы проданных копий)
# - <code>JP_sales</code> — продажи в Японии (миллионы проданных копий)
# - <code>Other_sales</code> — продажи в других странах (миллионы проданных копий)
# - <code>Critic_Score</code> — оценка критиков (максимум 100)
# - <code>User_Score</code> — оценка пользователей (максимум 10)
# - <code>Rating</code> — рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.

# %% [markdown]
# <b>СОДЕРЖАНИЕ</b>
# 1. <a href="#first">Открытие файла с данными и изучение общей информации</a>
#     1.1. <a href="#first-first">Импорт pandas. Запись данных в data</a>
#     1.2. <a href="#first-second">Изучение файла</a>
# 2. <a href="#second">Подготовка данных</a>
#     2.1. <a href="#second-first">Замена названий столбцов</a>
#     2.2. <a href="#second-second">Изменение типов данных</a>
#     2.3. <a href="#second-third">Пропущенные значения</a>
#     2.4. <a href="#second-fourth">Новый столбец: суммарные продажи во всех регионах</a>
# 3. <a href="#third">Исследовательский анализ данных</a>
#     3.1. <a href="#third-first">Количество игр за все периоды</a>
#     3.2. <a href="#third-second">Продажи по платформам</a>
#     3.3. <a href="#third-third">Какие платформы лидируют по продажам, растут или падают</a>
#     3.4. <a href="#third-fourth">«Ящик с усами» по глобальным продажам игр в разбивке по платформам</a>
#     3.5. <a href="#third-fifth">Влияние на продажи внутри одной популярной платформы</a>
# 4. <a href="#fourth">Составление портрета пользователя каждого региона</a>
#     4.1. <a href="#fourth-first">Самые популярные платформы (топ-5)</a>
#     4.2. <a href="#fourth-second">Самые популярные жанры (топ-5)</a>
#     4.3. <a href="#fourth-third">Влияние рейтинга ESRB на продажи в отдельном регионе</a>
# 5. <a href="#fifth">Проверка гипотез</a>
#     5.1. <a href="#fifth-first">Гипотеза 1</a>
#     5.2. <a href="#fifth-second">Гипотеза 2</a>
# 6. <a href="#sixth">Общий вывод</a>

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Отлично.
#
# </div>

# %% [markdown]
# ### <a class="anchor" id="first">Открытие файла с данными и изучение общей информации</a>

# %% [markdown]
# #### <a class="anchor" id="first-first">Импорт pandas. Запись данных в data</a>

# %%
# ипортировать библиотеки
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np 
import seaborn
from scipy import stats as st

# %%
# записать данные в data
try: 
    data = pd.read_csv('/datasets/games.csv', sep=',')
except:
    data = pd.read_csv('games.csv', sep=',')

# %% [markdown]
# #### <a class="anchor" id="first-second">Изучение данных</a>

# %%
# изучить файл: вывод первых строк
data.head(10)
# Out:
#                         Name Platform  Year_of_Release         Genre  \
# 0                 Wii Sports      Wii           2006.0        Sports
# 1          Super Mario Bros.      NES           1985.0      Platform
# 2             Mario Kart Wii      Wii           2008.0        Racing
# 3          Wii Sports Resort      Wii           2009.0        Sports
# 4   Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                     Tetris       GB           1989.0        Puzzle
# 6      New Super Mario Bros.       DS           2006.0      Platform
# 7                   Wii Play      Wii           2006.0          Misc
# 8  New Super Mario Bros. Wii      Wii           2009.0      Platform
# 9                  Duck Hunt      NES           1984.0       Shooter
#
#    NA_sales  EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     41.36     28.96      3.77         8.45          76.0          8      E
# ...

# %%
# изучить файл: метод info()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
# изучить файл: гистограммы
data.hist(figsize=(10, 10));

# %%
# определить размер data
data.shape
# Out:
# (16715, 11)

# %% [markdown]
# <b>ИТОГИ</b>
# 1. Импортирована библиотека pandas и открыт файл.
# 2. Изучен файл выводом первых 10 строк.
# 3. Изучен файл методом <i>info()</i>.
# 4. Построены гистограммы.

# %% [markdown]
# ### <a class="anchor" id="second">Подготовка данных</a>

# %% [markdown]
# #### <a class="anchor" id="second-first">Замена названий столбцов</a>

# %%
# привести названия столбцов к нижнему регистру
data.columns = data.columns.str.lower()

# %%
# проверка
data.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score user_score rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %% [markdown]
# #### <a class="anchor" id="second-second">Изменение типов данных</a>

# %% [markdown]
# После изучения данных я увидел, что <code>name</code>, <code>platform</code>, <code>genre</code> и <code>rating</code> имеют тип данных <i>Object</i>, это значит, что в данных столбцах текстовые или смешанные числовые и нечисловые значения. Нам это подходит, так как в данных стобцах находятся данные по названию игр, платформах, жанрах и рейтингу (выставляется буквой). <code>na_sales</code>, <code>eu_sales</code>, <code>jp_sales</code>, <code>other_sales</code> и <code>critic_score</code> имеют тип данных <i>Float64</i>, это значит, что в данных столбцах числа с плавающей точкой. Нам это подходит, так как в данных столбцах находятся данные по количеству продаж (в миллионах) и оценки.
#
# <code>year_of_release</code> имеет тип данных <i>Float64</i>, то есть в данном столбце находятся числа с плавающей точкой. Нам это <b>не</b> подходит, так как год - целое число. Нужно заменить на <i>Int64</i>. <code>user_score</code> имеет тип данных <i>Object</i>, то есть в данном столбце находятся текстовые или смешанные числовые и нечисловые значения. Нам это <b>не</b> подходит, так оценка пользователей - число с плавающей точкой. Нужно заменить на <i>Float64</i>.

# %%
# изменить тип данных year_of_release
data['year_of_release'] = data['year_of_release'].astype('Int64')

# %%
# изменить тип данных year_of_release
data['user_score'] = pd.to_numeric(data['user_score'], errors='coerce')

# %%
# проверка
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16446 non-null  Int64
#  3   genre            16713 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       7590 non-null   float64
#  10  rating           9949 non-null   object
# dtypes: Int64(1), float64(6), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# #### <a class="anchor" id="second-third">Пропущенные значения</a>

# %% [markdown]
# Всего строк в data <code>16715</code>, получается, что пропуски есть в следующих столбцах: <code>name</code>, <code>year_of_release</code>, <code>genre</code>, <code>critic_score</code>, <code>user_score</code>, <code>rating</code>.
#
# Самостоятельно точно определить причину пропусков будет затруднительно, но можно попробовать догадаться, что могли быть ошибки в выгрузке или ошибки при внесении данных в таблицу (например, в столбцах <code>name</code>, <code>year_of_release</code>, <code>genre</code>). Также может быть такое, что по некоторым играм просто нет доступной информации (например, в столбцах <code>critic_score</code>, <code>user_score</code>, <code>rating</code>). То есть просто не была получена полная и точная информация по оценкам и рейтингу для всех игр.
#
# Заполнить можно столбцы <code>rating</code> и <code>genre</code> значениями <i>Uknown</i>, так как значения в данных столбцах имеют тип данных <i>Object</i>.
#
# Пропущенные значения в остальных столбцах мы не можем самостоятельно заполнить, так как они могут в итоге исказить данные.

# %%
# заполнить пропуски в rating
data['rating'] = data['rating'].fillna('Uknown')

# %%
# заполнить пропуски в genre
data['genre'] = data['genre'].fillna('Uknown')

# %%
# проверка
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16446 non-null  Int64
#  3   genre            16715 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       7590 non-null   float64
#  10  rating           16715 non-null  object
# dtypes: Int64(1), float64(6), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# В <code>user_score</code> есть значения tbd.
#
# <i>Эта аббревиатура не скрывает в себе никаких таинственных смыслов и расшифровывается очень просто - To Be Determined, то есть "Будет определено"</i>.
#
# Это значит, что на момент выгрузки оценки нет, но она появится позже. Отсутствие оценки = пропущенное значение. Следовательно, можем заменить tbd на NaN. Если нужно специально присвоить значение NaN элементу структуры данных, для этого используется np.NaN (или np.nan) из библиотеки NumPy.

# %%
data['user_score'] = data['user_score'].replace('tbd', np.NaN)

# %%
# проверить, что в 'user_score' есть tbd
# false - нет строк, где в 'user_score' есть tbd
# true - есть строки, где в 'user_score' есть tbd
print((data['user_score'] == 'tbd').unique())
# Out:
# [False]

# %% [markdown]
# #### <a class="anchor" id="second-fourth">Новый столбец: суммарные продажи во всех регионах</a>

# %%
# добавить новый столбец
data['sales'] = data['na_sales'] + data['eu_sales'] + data['jp_sales']

# %%
# проверка
data.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii             2006        Sports     41.36
# 1         Super Mario Bros.      NES             1985      Platform     29.08
# 2            Mario Kart Wii      Wii             2008        Racing     15.68
# 3         Wii Sports Resort      Wii             2009        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB             1996  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score  rating  sales
# 0     28.96      3.77         8.45          76.0         8.0       E  74.09
# 1      3.58      6.81         0.77           NaN         NaN  Uknown  39.47
# 2     12.76      3.79         3.29          82.0         8.3       E  32.23
# 3     10.93      3.28         2.95          80.0         8.0       E  29.82
# 4      8.89     10.22         1.00           NaN         NaN  Uknown  30.38

# %% [markdown]
# <b>ИТОТИ</b>
# 1. <b>Заменены названия столбцов</b>
# Названия столбцов приведены к нижнему регистру
# 2. <b>Изменены типы данных</b>
# <code>year_of_release</code> имел тип данных <i>Float64</i>, сейчас тип данных изменён на <i>Int64</i>. <code>user_score</code> имел тип данных <i>Object</i>, сейчас тип данных изменён на <i>Float64</i>.
# 3. <b>Проведена работа с пропущенными значениями</b>
# Заполнены столбцы <code>rating</code> и <code>genre</code> значениями <i>Uknown</i>, так как значения в данных столбцах имеют тип данных <i>Object</i>. В <code>user_score</code> были значения tbd, с помощью np.NaN (или np.nan) из библиотеки NumPy эти значения были заменены на NaN.
# 4. <b>Добавление нового стобца</b>
# Был добавлен новый столбец <code>sales</code>, в котором просуммированы продажи по регионам.

# %% [markdown]
# ### <a class="anchor" id="third">Исследовательский анализ данных</a>

# %% [markdown]
# #### <a class="anchor" id="third-first">Количество игр за все периоды</a>

# %%
# сгруппировать данные и определить количество выпущенных игр по годам
games_for_years = data.groupby(['year_of_release'])['year_of_release'].count().to_frame()

# переименовать столбцы
#games_for_years.columns=['count']

games_for_years.plot(figsize=(15, 5));
games_for_years
# Out:
#                  year_of_release
# year_of_release
# 1980                           9
# 1981                          46
# 1982                          36
# 1983                          17
# 1984                          14
# 1985                          14
# 1986                          21
# 1987                          16
# 1988                          15
# 1989                          17
# 1990                          16
# 1991                          41
# 1992                          43
# 1993                          62
# 1994                         121
# 1995                         219
# 1996                         263
# 1997                         289
# 1998                         379
# 1999                         338
# 2000                         350
# 2001                         482
# 2002                         829
# 2003                         775
# 2004                         762
# 2005                         939
# 2006                        1006
# ...

# %% [markdown]
# <b>Вывод:</b> не все периоды стоит в дальнейшем учитывать. После 2011 года наблюдается уменьшение количества выпускаемых игр, поэтому для анализа можно брать данные с 2012 года.

# %% [markdown]
# #### <a class="anchor" id="third-second">Продажи по платформам</a>

# %%
# сгруппировать данные и определить топ-платформы по количеству продаж
games_for_platforms = (
    data.pivot_table(index=['platform'], values=['sales'], aggfunc='sum')
    .sort_values(by='sales', ascending=False)
)

games_for_platforms.head(5)
# Out:
#             sales
# platform
# PS2       1062.33
# X360       885.66
# Wii        828.44
# PS3        803.97
# DS         746.86

# %% [markdown]
# Топ-10 платформ по количеству продаж: <b>PS2</b>, <b>X360</b>, <b>Wii</b>, <b>PS3</b>, <b>DS</b>.
#
# Построим распределение по годам для данных платформ.

# %%
top_platforms = ['PS2', 'X360', 'Wii', 'PS3', 'DS']

for item in top_platforms:
    plot_for_top_platforms = (
        data[data['platform'] == item]
        .groupby('year_of_release')['sales'].sum())
    plot_for_top_platforms.name = item
    plot_for_top_platforms.plot(grid=True, legend=True, figsize=(15,5))

# %% [markdown]
# <b>Вывод:</b> за 8-10 лет появляются новые и исчезают старые платформы, но бывают исключения.

# %%
ds_check = (
    data[data['platform'] == 'DS']
    .groupby('year_of_release')['sales'].sum())
ds_check
# Out:
# year_of_release
# 1985      0.02
# 2004     15.91
# 2005    119.34
# 2006    111.64
# 2007    135.85
# 2008    134.37
# 2009    110.99
# 2010     79.48
# 2011     24.30
# 2012     10.42
# 2013      1.42
# Name: sales, dtype: float64

# %% [markdown]
# #### <a class="anchor" id="third-third">Какие платформы лидируют по продажам, растут или падают</a>

# %% [markdown]
# В пункте 3.2 я написал, что не все данные нужно будет учитывать, поэтому возьмём за актуальный период данные с 2012 года.

# %%
# перезапишем датафрейм
df = data[data['year_of_release'] > 2011]

# %%
# изучить платформы
platforms = df['platform'].unique()

for item in platforms:
    plot_for_top_platforms = (
        df[df['platform'] == item]
        .groupby('year_of_release')['sales'].sum()
    )
    plot_for_top_platforms.name = item
    plot_for_top_platforms.plot(grid=True, legend=True, figsize=(15,5))
    
# сгруппировать данные и определить топ-платформы по количеству продаж
platform_sales = (
    df.pivot_table(index=['platform'], values=['sales'], aggfunc='sum')
    .sort_values(by='sales', ascending=False)
)

platform_sales
# Out:
#            sales
# platform
# PS4       265.79
# PS3       245.53
# X360      216.14
# 3DS       185.74
# XOne      145.05
# WiiU       76.24
# PC         56.88
# PSV        43.38
# Wii        32.76
# DS         11.84
# PSP        11.02

# %%
# изучить платформы
platforms = df['platform'].unique()

for item in platforms:
    plot_for_top_platforms = (
        df[df['platform'] == item]
        .groupby('year_of_release')['sales'].sum()
    )
    plot_for_top_platforms.name = item
    plot_for_top_platforms.plot(grid=True, legend=True, figsize=(15,5))
    plt.ylim(0,7)

# %% [markdown]
# <b>Вывод:</b> По продажам лидируют следующие платформы: <b>PS4</b>, <b>PS3</b>, <b>X360</b>, <b>3DS</b>, <b>XOne</b>.
#
# По графику мы можем увидеть, что до 2015 года росли <b>PS4</b>, <b>XOne</b>. С 2015 года можно заметить, что продажи по платформам стали падать. К началу 2016 года лидировали <b>PS4</b>, <b>XOne</b> и <b>3DS</b>, они были потенциально прибыльными, поэтому можно остановиться на них. Также с 2015 по 2016 продажи выше 5 миллионов были у <b>PSV</b>, <b>X360</b>, <b>PC</b>, <b>PSP</b> и <b>WiiU</b>, их тоже можно оставить.

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍👍 Отлично.
#
# </div>

# %% [markdown]
# #### <a class="anchor" id="third-fourth">«Ящик с усами» по глобальным продажам игр в разбивке по платформам</a>

# %%
seaborn.boxplot(data=df, x='platform', y='sales', 
    flierprops={"marker": "x"}, width=0.8);
seaborn.set(rc={'figure.figsize':(10,5)})
plt.ylim([0,2])
plt.title('«Ящик с усами» по глобальным продажам игр в разбивке по платформам');
plt.show()

seaborn.boxplot(data=df, x='platform', y='sales', 
    flierprops={"marker": "x"}, width=0.8);
seaborn.set(rc={'figure.figsize':(10,5)})
plt.ylim([0,0.85])
plt.title('«Ящик с усами» по глобальным продажам игр в разбивке по платформам');
plt.show()

# %% [markdown]
# <b>Вывод:</b> По "ящику с усами" можно увидеть, что максимальные продажи у <code>X360</code>, <code>PS4</code>, <code>Wii</code>, <code>XOne</code>, <code>PS3</code>, <code>WiiU</code>. У всех этих приставок также примерно одинаковое медианное значение.
#
# Кажется, распределение в <code>PS3</code>, <code>X360</code>, <code>PS4</code>, <code>XOne</code>, <code>Wii</code>, <code>WiiU</code> более рассеяно: интервал P50-P75 большой, это значит, что встречаются игры, у которых продаже намного выше, но таких игр не так много, потому что медиана остаётся ниже.

# %% [markdown]
# #### <a class="anchor" id="third-fifth">Влияние на продажи внутри одной популярной платформы</a>

# %% [markdown]
# Необходимо посмотреть, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Возьмём для анализа PS4.

# %%
df[df['platform'] == 'PS4'].plot(kind='scatter',
        y='sales' , x='user_score', alpha=0.8, subplots=True, figsize=(15,5), c = 'b', s = 4);
plt.title('Диаграмма рассеяния — продажи PS4-оценка пользователей');
plt.show()

df[df['platform'] == 'X360'].plot(kind='scatter',
        y='sales' , x='user_score', alpha=0.8, subplots=True, figsize=(15,5), c = 'b', s = 4);
plt.title('Диаграмма рассеяния — продажи X360-оценка пользователей');
plt.show()

df[df['platform'] == 'WiiU'].plot(kind='scatter',
        y='sales' , x='user_score', alpha=0.8, subplots=True, figsize=(15,5), c = 'b', s = 4);
plt.title('Диаграмма рассеяния — продажи WiiU-оценка пользователей');
plt.show()

df[df['platform'] == 'Wii'].plot(kind='scatter',
        y='sales' , x='user_score', alpha=0.8, subplots=True, figsize=(15,5), c = 'b', s = 4);
plt.title('Диаграмма рассеяния — продажи Wii-оценка пользователей');
plt.show()
# Out:
# /Users/user/anaconda3/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:1259: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
# определить коэффециент корреляции
print('Коэффициент корреляции для всех платформ = ', df['user_score'].corr(df['sales']))
print('Коэффициент корреляции для PS4 = ', df[df['platform'] == 'PS4']['user_score'].corr(df[df['platform'] == 'PS4']['sales']))
print('Коэффициент корреляции для X360 = ', df[df['platform'] == 'X360']['user_score'].corr(df[df['platform'] == 'X360']['sales']))
print('Коэффициент корреляции для WiiU = ', df[df['platform'] == 'WiiU']['user_score'].corr(df[df['platform'] == 'WiiU']['sales']))
print('Коэффициент корреляции для Wii = ', df[df['platform'] == 'Wii']['user_score'].corr(df[df['platform'] == 'Wii']['sales']))
# Out:
# Коэффициент корреляции для всех платформ =  0.006814172437443832
# Коэффициент корреляции для PS4 =  -0.031260536866669214
# Коэффициент корреляции для X360 =  0.00656272309322537
# Коэффициент корреляции для WiiU =  0.39921099274998917
# Коэффициент корреляции для Wii =  0.2999488746803372

# %% [markdown]
# <b>Вывод:</b> отзывы пользователей для всех платформ не влияют на продажи. Также корреляции нет для PS4 и X360, но для японцев отзывы пользователей имеют значения, прослеживаятся слабая зависимость, но она есть.

# %%
df[df['platform'] == 'PS4'].plot(kind='scatter',
        y='sales' , x='critic_score', alpha=0.8, subplots=True, figsize=(15,5), c = 'b', s = 4);
plt.title('Диаграмма рассеяния — продажи PS4-оценка критиков');
plt.show()

df[df['platform'] == 'X360'].plot(kind='scatter',
        y='sales' , x='critic_score', alpha=0.8, subplots=True, figsize=(15,5), c = 'b', s = 4);
plt.title('Диаграмма рассеяния — продажи PS4-оценка критиков');
plt.show()

df[df['platform'] == 'WiiU'].plot(kind='scatter',
        y='sales' , x='critic_score', alpha=0.8, subplots=True, figsize=(15,5), c = 'b', s = 4);
plt.title('Диаграмма рассеяния — продажи PS4-оценка критиков');
plt.show()

df[df['platform'] == 'Wii'].plot(kind='scatter',
        y='sales' , x='critic_score', alpha=0.8, subplots=True, figsize=(15,5), c = 'b', s = 4);
plt.title('Диаграмма рассеяния — продажи PS4-оценка критиков');
plt.show()

# %%
# определить коэффециент корреляции
print('Коэффициент корреляции для всех платформ = ', df['critic_score'].corr(df['sales']))
print('Коэффициент корреляции для PS4 = ', df[df['platform'] == 'PS4']['critic_score'].corr(df[df['platform'] == 'PS4']['sales']))
print('Коэффициент корреляции для X360 = ', df[df['platform'] == 'X360']['critic_score'].corr(df[df['platform'] == 'X360']['sales']))
print('Коэффициент корреляции для WiiU = ', df[df['platform'] == 'WiiU']['critic_score'].corr(df[df['platform'] == 'WiiU']['sales']))
print('Коэффициент корреляции для Wii = ', df[df['platform'] == 'Wii']['critic_score'].corr(df[df['platform'] == 'Wii']['sales']))
# Out:
# Коэффициент корреляции для всех платформ =  0.3094494925975514
# Коэффициент корреляции для PS4 =  0.40588677465201295
# Коэффициент корреляции для X360 =  0.3602597690291541
# Коэффициент корреляции для WiiU =  0.3470616974485547
# Коэффициент корреляции для Wii =  -0.4229985071870359

# %% [markdown]
# <b>Вывод:</b> отзывы критиков незначительно влияют на продажи внутри одной популярной приставки и на продажи внутри всех платформ. Чем выше оценка критиков, тем выше продажи, но так бывает не всегда. Для платформы Wii заметна другая обратная зависимость.

# %% [markdown]
# #### <a class="anchor" id="third-sixth">Общее распределение игр по жанрам</a>

# %%
# сгруппировать данные и определить топ-платформы по количеству продаж
genre = (
    df.pivot_table(index=['genre'], values=['sales'], aggfunc=['mean', 'median'])
)
genre.columns=['sales_mean', 'sales_median']
genre.sort_values(by='sales_median', ascending=False)

# построить диаграмму
(
    genre.sort_values(by='sales_median')
    .plot(kind = 'barh', y='sales_median', figsize = (19,6), rot = 0, legend = False, fontsize = 16, color = 'SteelBlue')
    .set_title('Распределение игр по жанрам' + "\n", fontsize = 24)  
)

# вывести таблицу
genre
# Out:
#               sales_mean  sales_median
# genre
# Action          0.378254         0.110
# Adventure       0.088146         0.030
# Fighting        0.367156         0.130
# Misc            0.402969         0.120
# Platform        0.652000         0.190
# Puzzle          0.166786         0.040
# Racing          0.408783         0.120
# Role-Playing    0.481000         0.135
# Shooter         1.138170         0.380
# Simulation      0.411625         0.110
# Sports          0.591903         0.215
# Strategy        0.172958         0.070

# %% [markdown]
# <b>Вывод:</b> самыми прибыльными по жанрам оказались Shooter ("стрелялка"), Sports (спорт), Platform (прыжки по платформам, лазанье по лестницам). Это игры, в которых делается упор на эксплуатацию физических возможностей игрока, в том числе координации глаз и рук и скорости реакции. Из-за таких особенностей игра не надоедает игроку.
#
# Наименее прибыльными по жанрам оказались Adventure (приключения), Strategy (стратегии) и Puzzle (головоломки). Это игры, в которых для достижения цели игроку необходимо применять стратегическое мышление, логику, эрудицию. Такие игры могут подходить более усидчивым людям, у которых есть свободное время.

# %% [markdown]
# <b>ИТОГ</b>
#
# Отзывы пользователей для всех платформ не влияют на продажи. Также корреляции нет для PS4 и X360, но для японцев отзывы пользователей имеют значения, прослеживаятся слабая зависимость, но она есть.
#
# Отзывы критиков незначительно влияют на продажи внутри одной популярной приставки и на продажи внутри всех платформ. Чем выше оценка критиков, тем выше продажи, но так бывает не всегда. Для платформы Wii заметна другая обратная зависимость.
#
# Самыми прибыльными по жанрам оказались Shooter ("стрелялка"), Sports (спорт), Platform (прыжки по платформам, лазанье по лестницам). Это игры, в которых делается упор на эксплуатацию физических возможностей игрока, в том числе координации глаз и рук и скорости реакции. Из-за таких особенностей игра не надоедает игроку.
#
# Наименее прибыльными по жанрам оказались Adventure (приключения), Strategy (стратегии) и Puzzle (головоломки). Это игры, в которых для достижения цели игроку необходимо применять стратегическое мышление, логику, эрудицию. Такие игры могут подходить более усидчивым людям, у которых есть свободное время.

# %% [markdown]
# ### <a class="anchor" id="fourth">Составление портрета пользователя каждого региона</a>

# %% [markdown]
# #### <a class="anchor" id="fourth-first">Самые популярные платформы (топ-5)</a>

# %%
regions = ['na_sales', 'eu_sales', 'jp_sales']

for item in regions:
    top_platforms_region = (
    df.pivot_table(index=['platform'], values=item, aggfunc='sum')
    .sort_values(by=item, ascending=False)
    )
    top_platforms_region['доля'] = top_platforms_region[item] / sum(top_platforms_region[item])
    top_5_platforms_region = top_platforms_region.iloc[0:5]
    top_platforms_region[item].plot(kind='bar', legend=True, figsize=(15,5)) 
    plt.show()
    print(top_5_platforms_region)
# Out:
#           na_sales      доля
# platform
# X360        140.05  0.236983
# PS4         108.74  0.184003
# PS3         103.38  0.174933
# XOne         93.12  0.157571
# 3DS          55.31  0.093592
#           eu_sales      доля
# platform
# PS4         141.09  0.278383
# PS3         106.86  0.210844
# X360         74.52  0.147034
# XOne         51.59  0.101792
# 3DS          42.64  0.084132
#           jp_sales      доля
# platform
# 3DS          87.79  0.455862
# PS3          35.29  0.183249
# PSV          21.04  0.109253
# PS4          15.96  0.082875
# WiiU         13.01  0.067556

# %% [markdown]
# <b>Вывод:</b> в Северной Америке самыми популярными платформами стали <b>X360</b>, <b>PS4</b>, <b>PS3</b>, <b>XOne</b>, <b>3DS</b>. Доля только 5 популярных платформ составляет 0,847. Между <b>X360</b> и <b>PS4</b> есть довольно большой разрыв в долях. Такое распределение можно объяснить тем, что X360 является продуктом американской компании Microsoft.
#
# В Европе самыми популярными платформами стали <b>PS4</b>, <b>PS3</b>, <b>X360</b>, <b>XOne</b>, <b>3DS</b>. Доля только 5 популярных платформ составляет 0,822. Доли между <b>PS4</b> и <b>PS3</b> не такой большой.
#
# В Японии самыми популярными платформами стали <b>3DS</b>, <b>PS3</b>, <b>PSV</b>, <b>PS4</b>, <b>WiiU</b>. Доля только 5 популярных платформ составляет 0,899. Доли между <b>3DS</b>, <b>PS3</b> очень большой. Стоит отметить, что все пять мест занимают продкты японский компаний (Nintendo, Sony).

# %% [markdown]
# #### <a class="anchor" id="fourth-second">Самые популярные жанры (топ-5)</a>

# %%
regions = ['na_sales', 'eu_sales', 'jp_sales']

for item in regions:
    top_genre_region = (
    df.pivot_table(index=['genre'], values=item, aggfunc='sum')
    .sort_values(by=item, ascending=False)
    )
    top_genre_region['доля'] = top_genre_region[item] / sum(top_genre_region[item])
    top_5_genre_region = top_genre_region.iloc[0:5]
    for i in top_genre_region['доля']:
        if i not in top_5_genre_region['доля']:
            top_genre_region.replace(top_genre_region[item], 'other')
    fig1, ax1 = plt.subplots()
    ax1.pie(top_genre_region['доля'], labels=top_genre_region.index, autopct='%1.1f%%')
    ax1.axis('equal')  
    plt.title('Доля жанров')
    plt.show()
    print(top_5_genre_region)
# Out:
#               na_sales      доля
# genre
# Action          177.84  0.300929
# Shooter         144.77  0.244970
# Sports           81.53  0.137960
# Role-Playing     64.00  0.108297
# Misc             38.19  0.064623
#               eu_sales      доля
# genre
# Action          159.34  0.314392
# Shooter         113.47  0.223886
# Sports           69.09  0.136321
# Role-Playing     48.53  0.095754
# Racing           27.29  0.053846
#               jp_sales      доля
# genre
# Role-Playing     65.44  0.339807
# Action           52.80  0.274172
# Misc             12.86  0.066777
# Simulation       10.41  0.054055
# Fighting          9.44  0.049019

# %% [markdown]
# <b>Вывод:</b> в Европе и Северной Америке предпочитают похожие жанры игр: Action, Shooter, Sports, Role-Playing. В Японии же первое песто занимает жанр Role-Playing, а также в топе присутствуют Simulation и Fighting. После изучения дополнительных материалов выяснил, что в Японии появился поджанр Role-Playing, который называется JRPG. Большинство таких игр было разработано в Японии и в первую очередь для внутреннего японского рынка для игровых приставок. Жителям Японии нравится JRPG, а также большинство игр в этом поджанре эксклюзивно представлены на приставках японских производителей.

# %% [markdown]
# #### <a class="anchor" id="fourth-third">Влияние рейтинга ESRB на продажи в отдельном регионе</a>

# %%
regions = ['na_sales', 'eu_sales', 'jp_sales']

for item in regions:
    rating_region = (
    df.pivot_table(index=['rating'], values=item, aggfunc='sum')
    .sort_values(by=item, ascending=False)
    )
    rating_region['доля'] = rating_region[item] / sum(rating_region[item])
    rating_region[item].plot(kind='bar', legend=True, figsize=(15,5)) 
    plt.show()
    print(rating_region)
# Out:
#         na_sales      доля
# rating
# M         231.57  0.391847
# E         114.37  0.193529
# Uknown    103.31  0.174814
# E10+       75.70  0.128094
# T          66.02  0.111715
#         eu_sales      доля
# rating
# M         193.96  0.382700
# E         113.03  0.223018
# Uknown     91.50  0.180537
# E10+       55.37  0.109250
# T          52.96  0.104495
#         jp_sales      доля
# rating
# Uknown    108.84  0.565168
# E          28.33  0.147108
# T          26.02  0.135113
# M          21.20  0.110084
# E10+        8.19  0.042528

# %% [markdown]
# <b>Вывод:</b> в Европе и Северной Америке лидируют одинаоквые рейтинги с относительно похожими долями: для взрослых, для всех, для всех от 10 лет, для подростков. В Японии же рейтинги расположились немного по-другому: для всех, для подростков, для взрослых и для всех от 10 лет. Большую долю в Японии занимает Uknown.

# %% [markdown]
# <b>ИТОГ</b>
#
# В Северной Америке самыми популярными платформами стали <b>X360</b>, <b>PS4</b>, <b>PS3</b>, <b>XOne</b>, <b>3DS</b>. Доля только 5 популярных платформ составляет 0,847. Между <b>X360</b> и <b>PS4</b> есть довольно большой разрыв в долях. Такое распределение можно объяснить тем, что X360 является продуктом американской компании Microsoft.
#
# В Европе самыми популярными платформами стали <b>PS4</b>, <b>PS3</b>, <b>X360</b>, <b>XOne</b>, <b>3DS</b>. Доля только 5 популярных платформ составляет 0,822. Доли между <b>PS4</b> и <b>PS3</b> не такой большой.
#
# В Японии самыми популярными платформами стали <b>3DS</b>, <b>PS3</b>, <b>PSV</b>, <b>PS4</b>, <b>WiiU</b>. Доля только 5 популярных платформ составляет 0,899. Доли между <b>3DS</b>, <b>PS3</b> очень большой. Стоит отметить, что все пять мест занимают продкты японский компаний (Nintendo, Sony).
#
# В Европе и Северной Америке предпочитают похожие жанры игр: Action, Shooter, Sports, Role-Playing. В Японии же первое песто занимает жанр Role-Playing, а также в топе присутствуют Simulation и Fighting.
#
# В Европе и Северной Америке лидируют одинаоквые рейтинги с относительно похожими долями: для взрослых, для всех, для всех от 10 лет, для подростков. В Японии же рейтинги расположились немного по-другому: для всех, для подростков, для взрослых и для всех от 10 лет.

# %% [markdown]
# ### <a class="anchor" id="first">Проверка гипотез</a>

# %% [markdown]
# #### <a class="anchor" id="fifth-first">Гипотеза 1</a>

# %% [markdown]
# Проверка гипотезы: Средние пользовательские рейтинги платформ Xbox One и PC одинаковые;
#
# ```
# H_0: Средний пользовательский рейтинг Xbox One = Средний пользовательский рейтинг PC
# H_a: Средний пользовательский рейтинг Xbox One ≠ Средний пользовательский рейтинг PC
# alpha = 0.05
# ```

# %%
df_new = df.dropna(subset=['user_score'])

xone = df_new[df_new['platform']=='XOne']['user_score']
pc = df_new[df_new['platform']=='PC']['user_score']

results = st.ttest_ind(xone, pc, equal_var = False)

alpha = .05

# вывод значения p-value на экран 
print(results.pvalue)
# условный оператор с выводом строки с ответом
if results.pvalue > alpha:
    print('Не получилось отвергнуть нулевую гипотезу')
else:
    print('Отвергаем нулевую гипотезу')
# Out:
# 0.5489537965134912
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# <b>Вывод:</b> мы можем сказать, что средние пользовательские рейтинги платформ Xbox One и PC одинаковые.

# %% [markdown]
# #### <a class="anchor" id="fifth-second">Гипотеза 2</a>

# %% [markdown]
# Проверка гипотезы: Средние пользовательские рейтинги жанров Action и Sports разные;
#
# ```
# H_0: Средний пользовательский рейтинг Action = Средний пользовательский рейтинг Sports
# H_a: Средний пользовательский рейтинг Action ≠ Средний пользовательский рейтинг Sports
# alpha = 0.05
# ```

# %%
df_new = df.dropna(subset=['user_score'])

action = df_new[df_new['genre']=='Action']['user_score']
sports = df_new[df_new['genre']=='Sports']['user_score']

results = st.ttest_ind(action, sports, equal_var = False)

alpha = .05

# вывод значения p-value на экран 
print(results.pvalue)
# условный оператор с выводом строки с ответом
if results.pvalue > alpha:
    print('Не получилось отвергнуть нулевую гипотезу')
else:
    print('Отвергаем нулевую гипотезу')
# Out:
# 4.24307776572644e-20
# Отвергаем нулевую гипотезу

# %% [markdown]
# <b>Вывод:</b> мы можем сказать, что средние пользовательские рейтинги жанров Action и Sports разные.

# %% [markdown]
# ### <a class="anchor" id="sixth">Общий вывод</a>

# %% [markdown]
# 1. <b>Была проведена предобработка данных</b>
#     - Определено, в каких столбцах были пропуски.
#     - Заполнены пропущенные значения там, где это возможно.
#         - Заменены названия столбцов
#         Названия столбцов приведены к нижнему регистру
#         - Изменены типы данных
#         <code>year_of_release</code> имел тип данных <i>Float64</i>, сейчас тип данных изменён на <i>Int64</i>. <code>user_score</code> имел тип данных <i>Object</i>, сейчас тип данных изменён на <i>Float64</i>.
#         - Проведена работа с пропущенными значениями
#         -Заполнены столбцы <code>rating</code> и <code>genre</code> значениями <i>Uknown</i>, так как значения в данных столбцах имеют тип данных <i>Object</i>. В <code>user_score</code> были значения tbd, с помощью np.NaN (или np.nan) из библиотеки NumPy эти значения были заменены на NaN.
#         - Добавление нового стобца</b>
#         Был добавлен новый столбец <code>sales</code>, в котором просуммированы продажи по регионам.
#     - Указаны причины, которые могли привести к пропускам в данных
#
# 2. <b>Был проведён исследовательский анализ данных</b>
#     Были сформулированы следующие выводы:
#     - Отзывы пользователей для всех платформ не влияют на продажи. Также корреляции нет для PS4 и X360, но для японцев отзывы пользователей имеют значения, прослеживаятся слабая зависимость, но она есть.
#     - Отзывы критиков незначительно влияют на продажи внутри одной популярной приставки и на продажи внутри всех платформ. Чем выше оценка критиков, тем выше продажи, но так бывает не всегда. Для платформы Wii заметна другая обратная зависимость.
#     - Самыми прибыльными по жанрам оказались Shooter ("стрелялка"), Sports (спорт), Platform (прыжки по платформам, лазанье по лестницам). Это игры, в которых делается упор на эксплуатацию физических возможностей игрока, в том числе координации глаз и рук и скорости реакции. Из-за таких особенностей игра не надоедает игроку.
#
# Наименее прибыльными по жанрам оказались Adventure (приключения), Strategy (стратегии) и Puzzle (головоломки). Это игры, в которых для достижения цели игроку необходимо применять стратегическое мышление, логику, эрудицию. Такие игры могут подходить более усидчивым людям, у которых есть свободное время.
#
# 3. <b>Был составлен портрет пользователя каждого региона</b>
#     Были сформулированы следующие выводы:
#     - В Северной Америке самыми популярными платформами стали <b>X360</b>, <b>PS4</b>, <b>PS3</b>, <b>XOne</b>, <b>3DS</b>. Доля только 5 популярных платформ составляет 0,847. Между <b>X360</b> и <b>PS4</b> есть довольно большой разрыв в долях. Такое распределение можно объяснить тем, что X360 является продуктом американской компании Microsoft.
#     - В Европе самыми популярными платформами стали <b>PS4</b>, <b>PS3</b>, <b>X360</b>, <b>XOne</b>, <b>3DS</b>. Доля только 5 популярных платформ составляет 0,822. Доли между <b>PS4</b> и <b>PS3</b> не такой большой.
#     - В Японии самыми популярными платформами стали <b>3DS</b>, <b>PS3</b>, <b>PSV</b>, <b>PS4</b>, <b>WiiU</b>. Доля только 5 популярных платформ составляет 0,899. Доли между <b>3DS</b>, <b>PS3</b> очень большой. Стоит отметить, что все пять мест занимают продкты японский компаний (Nintendo, Sony).
#     - В Европе и Северной Америке предпочитают похожие жанры игр: Action, Shooter, Sports, Role-Playing. В Японии же первое песто занимает жанр Role-Playing, а также в топе присутствуют Simulation и Fighting.
#     - В Европе и Северной Америке лидируют одинаоквые рейтинги с относительно похожими долями: для взрослых, для всех, для всех от 10 лет, для подростков. В Японии же рейтинги расположились немного по-другому: для всех, для подростков, для взрослых и для всех от 10 лет.
#
# 4. <b>Были проверены гипотезы</b>
#     Были сформулированы следующие выводы:
#     - Гипотезу о том, что средние пользовательские рейтинги платформ Xbox One и PC одинаковые, можно принять.
#     - Гипотезы о том, что средние пользовательские рейтинги жанров Action и Sports разные, принять можно.
